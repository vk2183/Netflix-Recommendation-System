# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import datetime 
from wordcloud import WordCloud

# %%
data = pd.read_csv('/content/drive/MyDrive/datasets/netflix_titles 2.csv')

# %%
data.shape
# Out:
# (7787, 12)

# %%
data.head()
# Out:
#   show_id  ...                                        description
# 0      s1  ...  In a future where the elite inhabit an island ...
# 1      s2  ...  After a devastating earthquake hits Mexico Cit...
# 2      s3  ...  When an army recruit is found dead, his fellow...
# 3      s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4      s5  ...  A brilliant group of students become card-coun...
#
# [5 rows x 12 columns]

# %%
print ('These columns have the missing values:')
print (data.isnull().any())
# Out:
# These columns have the missing values:
# show_id         False
# type            False
# title           False
# director         True
# cast             True
# country          True
# date_added       True
# release_year    False
# rating           True
# duration        False
# listed_in       False
# description     False
# dtype: bool

# %%
#direector,cast,country,date_added,rating have few missing values

# %%
print(data.isnull().sum())
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
print(data.isnull().sum().sum())
# Out:
# 3631

# %%
data["director"].fillna('No Director',inplace=True)
data["cast"].fillna('No Cast',inplace=True)
data["country"].fillna('No country',inplace=True)
data.dropna(subset=["date_added","rating"],inplace=True)

# %%
data.isnull().any()
# Out:
# show_id         False
# type            False
# title           False
# director        False
# cast            False
# country         False
# date_added      False
# release_year    False
# rating          False
# duration        False
# listed_in       False
# description     False
# dtype: bool

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7782    False
# 7783    False
# 7784    False
# 7785    False
# 7786    False
# Length: 7770, dtype: bool

# %%
#remove months in date added
x = data["date_added"]
data["date_added"] = data["date_added"].str[-4:]
data.rename(columns= {"date_added":"year_added"},inplace=True)

# %%
data.head()
# Out:
#   show_id  ...                                        description
# 0      s1  ...  In a future where the elite inhabit an island ...
# 1      s2  ...  After a devastating earthquake hits Mexico Cit...
# 2      s3  ...  When an army recruit is found dead, his fellow...
# 3      s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4      s5  ...  A brilliant group of students become card-coun...
#
# [5 rows x 12 columns]

# %%
#ratings also put accordinglyy
z = set(data["rating"])
z
# Out:
# {'G',
#  'NC-17',
#  'NR',
#  'PG',
#  'PG-13',
#  'R',
#  'TV-14',
#  'TV-G',
#  'TV-MA',
#  'TV-PG',
#  'TV-Y',
#  'TV-Y7',
#  'TV-Y7-FV',
#  'UR'}

# %%
# change duration from seasons to minutes

# %%
data["cast"]
# Out:
# 0       João Miguel, Bianca Comparato, Michel Gomes, R...
# 1       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3       Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
#                               ...
# 7782    Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784                                              Nasty C
# 7785                           Adriano Zumbo, Rachel Khoo
# 7786                                              No Cast
# Name: cast, Length: 7770, dtype: object

# %%
data["listed_in"]
# Out:
# 0       International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                            Dramas, International Movies
# 2                     Horror Movies, International Movies
# 3       Action & Adventure, Independent Movies, Sci-Fi...
# 4                                                  Dramas
#                               ...
# 7782                         Dramas, International Movies
# 7783       Dramas, International Movies, Music & Musicals
# 7784    Documentaries, International Movies, Music & M...
# 7785                   International TV Shows, Reality TV
# 7786                      Documentaries, Music & Musicals
# Name: listed_in, Length: 7770, dtype: object

# %%
set(data["rating"])
# Out:
# {'G',
#  'NC-17',
#  'NR',
#  'PG',
#  'PG-13',
#  'R',
#  'TV-14',
#  'TV-G',
#  'TV-MA',
#  'TV-PG',
#  'TV-Y',
#  'TV-Y7',
#  'TV-Y7-FV',
#  'UR'}

# %%
set(data["rating"])
# Out:
# {'G',
#  'NC-17',
#  'NR',
#  'PG',
#  'PG-13',
#  'R',
#  'TV-14',
#  'TV-G',
#  'TV-MA',
#  'TV-PG',
#  'TV-Y',
#  'TV-Y7',
#  'TV-Y7-FV',
#  'UR'}

# %%
data["rating"].replace(['G',"NC-17","R","NR","PG","PG-13","TV-14","TV-G","TV-MA","TV-PG","TV-Y","TV-Y7","TV-Y7-FV","UR"],[0,17,17,18,7,13,16,0,17,17,14,7,7,0],inplace=True)
set(data["rating"])
# Out:
# {0, 7, 13, 14, 16, 17, 18}

# %%
data.head()
# Out:
#   show_id  ...                                        description
# 0      s1  ...  In a future where the elite inhabit an island ...
# 1      s2  ...  After a devastating earthquake hits Mexico Cit...
# 2      s3  ...  When an army recruit is found dead, his fellow...
# 3      s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4      s5  ...  A brilliant group of students become card-coun...
#
# [5 rows x 12 columns]

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'year_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
data.rename(columns={"rating":"min_age_req"},inplace=True)

# %%
data.head()
# Out:
#   show_id  ...                                        description
# 0      s1  ...  In a future where the elite inhabit an island ...
# 1      s2  ...  After a devastating earthquake hits Mexico Cit...
# 2      s3  ...  When an army recruit is found dead, his fellow...
# 3      s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4      s5  ...  A brilliant group of students become card-coun...
#
# [5 rows x 12 columns]

# %%
import seaborn as sns
sns.countplot(data["type"])
fig = plt.gcf()
fig.set_size_inches(9,9)
plt.title("TV shows vs Movies")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'TV shows vs Movies')

# %%
#seperate TV shows and Movies

# %%
sns.countplot(data["min_age_req"])
fig = plt.gcf()
fig.set_size_inches(5,5)
plt.title("Min age required")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Min age required')

# %%
sns.countplot(data["year_added"])
fig = plt.gcf()
fig.set_size_inches(9,9)
plt.title("Year added")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Year added')

# %%
sns.countplot(data["release_year"])
fig = plt.gcf()
fig.set_size_inches(40,9)
plt.title("Year released")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Year released')

# %%
data.type.unique()
# Out:
# array(['TV Show', 'Movie'], dtype=object)

# %%
data2=data[data["type"]=="TV Show"]
data2.head()
# Out:
#    show_id  ...                                        description
# 0       s1  ...  In a future where the elite inhabit an island ...
# 5       s6  ...  A genetics professor experiments with a treatm...
# 11     s12  ...  In this dark alt-history thriller, a naïve law...
# 12     s13  ...  Archival video and new interviews examine Mexi...
# 16     s17  ...  As a psychology professor faces Alzheimer's, h...
#
# [5 rows x 12 columns]

# %%
data2.rename(columns= {"duration":"seasons"},inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
data2.head()
# Out:
#    show_id  ...                                        description
# 0       s1  ...  In a future where the elite inhabit an island ...
# 5       s6  ...  A genetics professor experiments with a treatm...
# 11     s12  ...  In this dark alt-history thriller, a naïve law...
# 12     s13  ...  Archival video and new interviews examine Mexi...
# 16     s17  ...  As a psychology professor faces Alzheimer's, h...
#
# [5 rows x 12 columns]

# %%
data.head()
# Out:
#   show_id  ...                                        description
# 0      s1  ...  In a future where the elite inhabit an island ...
# 1      s2  ...  After a devastating earthquake hits Mexico Cit...
# 2      s3  ...  When an army recruit is found dead, his fellow...
# 3      s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4      s5  ...  A brilliant group of students become card-coun...
#
# [5 rows x 12 columns]

# %%
data1=data[data["type"]=="Movie"]

# %%
data1.head()
# Out:
#   show_id  ...                                        description
# 1      s2  ...  After a devastating earthquake hits Mexico Cit...
# 2      s3  ...  When an army recruit is found dead, his fellow...
# 3      s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4      s5  ...  A brilliant group of students become card-coun...
# 6      s7  ...  After an awful accident, a couple admitted to ...
#
# [5 rows x 12 columns]

# %%
data1.head()
# Out:
#   show_id  ...                                        description
# 1      s2  ...  After a devastating earthquake hits Mexico Cit...
# 2      s3  ...  When an army recruit is found dead, his fellow...
# 3      s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4      s5  ...  A brilliant group of students become card-coun...
# 6      s7  ...  After an awful accident, a couple admitted to ...
#
# [5 rows x 12 columns]

# %%
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='black',
                          width=1920,
                          height=1080
                         ).generate(" ".join(data.country))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('country.png')
plt.show()

# %%
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='black',
                          width=1920,
                          height=1080
                         ).generate(" ".join(data.director))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('director.png')
plt.show()

# %%
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='#FBCEB1',
                          width=1920,
                          height=1080
                         ).generate(" ".join(data2.listed_in))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('category.png')
plt.show()

# %%
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='black',
                          width=1920,
                          height=900
                         ).generate(" ".join(data1.country))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('country.png')
plt.show()

# %%
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='black',
                          width=1920,
                          height=900
                         ).generate(" ".join(data2.country))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('country.png')
plt.show()

# %%
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='yellow',
                          width=1920,
                          height=900
                         ).generate(" ".join(data1.cast))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('cast.png')
plt.show()

# %%
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='teal',
                          width=1920,
                          height=1080
                         ).generate(" ".join(data1.listed_in))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('category.png')
plt.show()
